# %%
import pandas as pd #importar a biblioteca pandas

# %%
df = pd.read_csv('C:/Users/dsadm/Desktop/IABD-Vitor/Bases_de_dados/creditcard.csv', sep=',')#comando para ler o arquivo csv da base de dados

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail(10)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284797  172782.0  -0.241923   0.712247  0.399806 -0.463406  0.244531
# 284798  172782.0   0.219529   0.881246 -0.635891  0.960928 -0.152971
# 284799  172783.0  -1.775135  -0.004235  1.189786  0.331096  1.196063
# 284800  172784.0   2.039560  -0.175233 -1.196825  0.234580 -0.008713
# 284801  172785.0   0.120316   0.931005 -0.546012 -0.745097  1.130314
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284797 -1.343668  0.929369 -0.206210  0.106234  ... -0.228876 -0.514376
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
n_transacoes = df['Class'].count()
n_transacoes
# Out:
# 284807

# %%
n_fraudes = df['Class'].sum() #soma os valores de fraudes
n_fraudes
# Out:
# 492

# %%
#calculo da quatnidad ede transacoes normais do dataframe
n_normais = n_transacoes - n_fraudes
n_normais
# Out:
# 284315

# %%
df['Class'].value_counts()# conta o numero de transacoes
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
n_porcetntagem_normais = n_normais/n_transacoes

n_porcetntagem_normais 

n_porcentagem_fraudes = n_fraudes/n_transacoes
n_porcentagem_fraudes
# Out:
# 0.001727485630620034

# %%
n_porcentagem_fraudes  = (n_fraudes/n_transacoes)*100
print(f'Porcentagem de transacoes com fraudes {n_porcentagem_fraudes}')
n_porcentagem_normais = (n_normais/n_transacoes)*100
print(f'Porcentagem de transacoes normais {n_porcentagem_normais}')
# Out:
# Porcentagem de transacoes com fraudes 0.1727485630620034
# Porcentagem de transacoes normais 99.82725143693798

# %%
#Definindo as variavies para o modelo 
X = df.drop('Class',axis = 1).values # exclui a coluna class
y = df['Class'].values # armazena em y a coluna class

# %%
from sklearn.model_selection import StratifiedShuffleSplit #importa o modelo para dividir o data frame

# %%
validador = StratifiedShuffleSplit(n_splits=1, test_size=0.1, random_state=0)

# %%
for treino_id, teste_id in validador.split(X,y):
    x_train,x_test = X[treino_id],X[teste_id]
    y_train,y_test = y[treino_id],y[teste_id]

# %%
from sklearn import tree # importa da biblioteca sklearn o metodo tree
classificador_arvore = tree.DecisionTreeClassifier() #variavel que armazena a arvore

# %%
arvore = classificador_arvore.fit(x_train,y_train)#Cria modelo de arvore de decisao

# %%
y_pred = arvore.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
def validador(X,y):
    validador = StratifiedShuffleSplit(n_splits=1,test_size=0.1, random_state=0)
    for treino_id, teste_id in validador.split(X,y):
        x_train, x_test = X[treino_id], X[teste_id]
        y_train, y_test = y[treino_id], y[teste_id]
    return x_train, x_test, y_train, y_test

# %%
def executar_classificador(classificador, x_train,y_train,x_test,y_test):
    arvore= classificador.fit(x_train,y_train)
    y_pred = arvore.predict(x_test)
    return y_pred

# %%
classificador_arvore_decisao = tree.DecisionTreeClassifier()
y_pred_arvore_decisao = executar_classificador(classificador_arvore_decisao, x_train, 
y_train,x_test, y_test)
import matplotlib.pyplot as plt
def salvar_arvore(classificador_arvore_decisao,nome):
    plt.figure(figsize=(200,100))
    tree.plot_tree(classificador_arvore_decisao,filled = True, fontsize=14)
    plt.savefig(nome)    
    plt.close()

# %%
salvar_arvore(classificador_arvore_decisao,"arvore transações-bancarias.jpg")
